# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N_max = 50
res = 1000
x = np.linspace(-3*np.pi-1, +3*np.pi+1, res)

def b(n):
    return -2*np.cos(n*np.pi)/n


y = np.array([0]* res)

for n in range(1, N_max):
    y = y + b(n)*np.sin(n*x)

#plottinng the Fourier series:
plt.figure(figsize=(12, 6))

xticks_positions = [-3*np.pi, -2*np.pi, -1*np.pi, 0, 1*np.pi, 2*np.pi, 3*np.pi]
yticks_positions = [-np.pi, 0, np.pi]

plt.ylim(-np.pi -0.5, np.pi + 0.5)

xtick_labels = [r"$-3\pi$", r"$-2\pi$", r"$-1\pi$", r"$0$", r"$1\pi$", r"$2\pi$", r"$3\pi$"]
ytick_labels = [r"$-1\pi$", r"$0$", r"$1\pi$"]

plt.xticks(xticks_positions, xtick_labels, alpha=0.6)
plt.yticks(yticks_positions, ytick_labels, alpha=0.6)

plt.grid(True)

plt.plot(x,y)
plt.plot(x, x)

# %%
N1 = 5
N2 = 10
N3 = 20
N4 = 50


y1 = np.array([0]* res)
for n in range(1, N1):
    y1 = y1 + b(n)*np.sin(n*x)


y2 = np.array([0]* res)
for n in range(1, N2):
    y2 = y2 + b(n)*np.sin(n*x)

y3 = np.array([0]* res)
for n in range(1, N3):
    y3 = y3 + b(n)*np.sin(n*x)

y4 = np.array([0]* res)
for n in range(1, N4):
    y4 = y4 + b(n)*np.sin(n*x)


plt.figure(figsize=(12, 6))

# N1
plt.subplot(221)
xticks_positions = [-3*np.pi, -2*np.pi, -1*np.pi, 0, 1*np.pi, 2*np.pi, 3*np.pi]
yticks_positions = [-np.pi, 0, np.pi]

plt.ylim(-np.pi -0.5, np.pi + 0.5)

xtick_labels = [r"$-3\pi$", r"$-2\pi$", r"$-1\pi$", r"$0$", r"$1\pi$", r"$2\pi$", r"$3\pi$"]
ytick_labels = [r"$-1\pi$", r"$0$", r"$1\pi$"]

plt.xticks(xticks_positions, xtick_labels, alpha=0.6)
plt.yticks(yticks_positions, ytick_labels, alpha=0.6)

plt.grid(True)
plt.gca().set_title(f'N = {N1}')

plt.plot(x,y1)

# N2
plt.subplot(222)
xticks_positions = [-3*np.pi, -2*np.pi, -1*np.pi, 0, 1*np.pi, 2*np.pi, 3*np.pi]
yticks_positions = [-np.pi, 0, np.pi]

plt.ylim(-np.pi -0.5, np.pi + 0.5)

xtick_labels = [r"$-3\pi$", r"$-2\pi$", r"$-1\pi$", r"$0$", r"$1\pi$", r"$2\pi$", r"$3\pi$"]
ytick_labels = [r"$-1\pi$", r"$0$", r"$1\pi$"]

plt.xticks(xticks_positions, xtick_labels, alpha=0.6)
plt.yticks(yticks_positions, ytick_labels, alpha=0.6)

plt.grid(True)
plt.gca().set_title(f'N = {N2}')

plt.plot(x,y2)


# N3
plt.subplot(223)
xticks_positions = [-3*np.pi, -2*np.pi, -1*np.pi, 0, 1*np.pi, 2*np.pi, 3*np.pi]
yticks_positions = [-np.pi, 0, np.pi]

plt.ylim(-np.pi -0.5, np.pi + 0.5)

xtick_labels = [r"$-3\pi$", r"$-2\pi$", r"$-1\pi$", r"$0$", r"$1\pi$", r"$2\pi$", r"$3\pi$"]
ytick_labels = [r"$-1\pi$", r"$0$", r"$1\pi$"]

plt.xticks(xticks_positions, xtick_labels, alpha=0.6)
plt.yticks(yticks_positions, ytick_labels, alpha=0.6)

plt.grid(True)
plt.gca().set_title(f'N = {N3}')

plt.plot(x,y3)

# N4

plt.subplot(224)
xticks_positions = [-3*np.pi, -2*np.pi, -1*np.pi, 0, 1*np.pi, 2*np.pi, 3*np.pi]
yticks_positions = [-np.pi, 0, np.pi]

plt.ylim(-np.pi -0.5, np.pi + 0.5)

xtick_labels = [r"$-3\pi$", r"$-2\pi$", r"$-1\pi$", r"$0$", r"$1\pi$", r"$2\pi$", r"$3\pi$"]
ytick_labels = [r"$-1\pi$", r"$0$", r"$1\pi$"]

plt.xticks(xticks_positions, xtick_labels, alpha=0.6)
plt.yticks(yticks_positions, ytick_labels, alpha=0.6)

plt.grid(True)
plt.gca().set_title(f'N = {N4}')

plt.plot(x,y4)
plt.savefig("Fourier.pdf", bbox_inches = 'tight')
