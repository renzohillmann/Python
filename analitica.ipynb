# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

import math

#parameters
E = 10
b = 8
c1 = 0
c2 = 10
k = 1

x = np.linspace(-3,3,1000000)

fig = plt.figure(figsize=(6,6))
P1 = k*np.sqrt( E - c1/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))
P11 = -k*np.sqrt( E - c1/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))

P2 = k*np.sqrt( E - c2/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))
P22 = -k*np.sqrt( E - c2/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))
ax = fig.add_subplot(1,1,1)
ax.spines["bottom"].set_position("zero")
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")
#ax.xaxis.set_ticks_position("bottom")
ax.yaxis.set_ticks_position("left")
ax.set_xlim([-3, 3.3])
ax.set_ylim([-5,5])
#plt.xlabel(' $\theta$', fontsize=16)
#plt.ylabel('Amplitud (m)', fontsize = 16)
plt.text(-2.9, 4.3, r'$P_{\theta}$', fontsize=40)
plt.text(3.1, 0.2, r'$\theta$', fontsize=40)
plt.plot(x, P1, color="#380282", linewidth=3)
plt.plot(x, P11, color="#380282", linewidth=3)
#plt.plot(x, P2, color="r", linewidth=2)
#plt.plot(x, P22, color="r", linewidth=2)

plt.savefig("1.pdf")
# Out:
# C:\Users\RENZO\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in sqrt
# C:\Users\RENZO\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in sqrt

# %%
E = 10
b = 8
c1 = 0
-+---+-++++++++++++++++++++++++++++++++++++++++++++++++++++------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------++---+-+++-++-+-++++++++++++++++++++++++++++++++++++++----------------------------------++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++-++....................................++++++++++++++++-----------+++++++++++++++++++++++++++++++++






+++++++++
c2 = 1
c3 = 2
c4 = 4
c5 = 6
c6 = 8
c7 = 10
c8 = 12
k = 1

x = np.linspace(0,math.pi,1000000)

P1 = k*np.sqrt( E - c1/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))
P11 = -k*np.sqrt( E - c1/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))

P2 = k*np.sqrt( E - c2/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))
P22 = -k*np.sqrt( E - c2/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))

P3 = k*np.sqrt( E - c3/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))
P33 = -k*np.sqrt( E - c3/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))

P4 = k*np.sqrt( E - c4/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))
P44 = -k*np.sqrt( E - c4/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))

P5 = k*np.sqrt( E - c5/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))
P55 = -k*np.sqrt( E - c5/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))

P6 = k*np.sqrt( E - c6/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))
P66 = -k*np.sqrt( E - c6/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))

P7 = k*np.sqrt( E - c7/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))
P77 = -k*np.sqrt( E - c7/(1 - np.power(np.cos(x), 2)) + b*np.cos(x))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1)
ax.spines["bottom"].set_position("zero")
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")
#ax.xaxis.set_ticks_position("bottom")
ax.yaxis.set_ticks_position("left")
ax.set_xlim([0, 3.3])
ax.set_ylim([-5,5])
#plt.xlabel(' $\theta$', fontsize=16)
#plt.ylabel('Amplitud (m)', fontsize = 16)
plt.text(0, 4.4, r'$P_{\theta}$', fontsize=20)
plt.text(3.1, 0.2, r'$\theta$', fontsize=20)

plt.plot(x, P1, color="#380282", linewidth=3)
plt.plot(x, P11, color="#380282", linewidth=3)
plt.plot(x, P2, color="r", linewidth=2)
plt.plot(x, P22, color="r", linewidth=2)
plt.plot(x, P3, color="g", linewidth=2)
plt.plot(x, P33, color="g", linewidth=2)
plt.plot(x, P4, color="lightseagreen", linewidth=2)
plt.plot(x, P44, color="lightseagreen", linewidth=2)
plt.plot(x, P5, color="m", linewidth=2)
plt.plot(x, P55, color="m", linewidth=2)
plt.plot(x, P6, color="darkorange", linewidth=2)
plt.plot(x, P66, color="darkorange", linewidth=2)
plt.plot(x, P7, color="orangered", linewidth=2)
plt.plot(x, P77, color="orangered", linewidth=2)


#plt.savefig("2.pdf")
# Out:
# C:\Users\RENZO\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app
# C:\Users\RENZO\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()
# C:\Users\RENZO\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\RENZO\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in sqrt
# C:\Users\RENZO\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\RENZO\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in sqrt
# C:\Users\RENZO\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: divide by zero encountered in true_divide
# ...
