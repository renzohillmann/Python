# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy import optimize
import numpy as np
import math as math

plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"

#espectro del mercurio
with open("I1.txt") as sum:
    
    lines = sum.readlines()
    x = [float(line.split()[0]) for line in lines]
    y = [float(line.split()[1]) for line in lines]
    
x = np.array(x)
y = np.array(y)
# 


#popt, pcov = optimize.curve_fit(gaussian, x, y , [1, -22.5, 1] )

#print (popt)
fig = plt.figure(figsize=(15,9))

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x,y, "darkviolet")

#axes.set_title("", fontsize=20)
axes.set_xlabel("V [V]", fontsize=25)
axes.set_ylabel("I  [$\\rho$ A]", fontsize=25)
axes.tick_params(axis="x", labelsize=20)
axes.tick_params(axis="y", labelsize=20)



plt.savefig("I1.pdf")

# %%
with open("I1.txt") as sum:
    
    lines = sum.readlines()
    x1 = [float(line.split()[0]) for line in lines]
    y1 = [float(line.split()[1]) for line in lines]
    
x1 = np.array(x1)
y1 = np.array(y1)

with open("I2.txt") as sum:
    
    lines = sum.readlines()
    x2 = [float(line.split()[0]) for line in lines]
    y2 = [float(line.split()[1]) for line in lines]
    
x2 = np.array(x2)
y2 = np.array(y2)

with open("I3.txt") as sum:
    
    lines = sum.readlines()
    x3 = [float(line.split()[0]) for line in lines]
    y3 = [float(line.split()[1]) for line in lines]
    
x3 = np.array(x3)
y3 = np.array(y3)

with open("I4.txt") as sum:
    
    lines = sum.readlines()
    x4 = [float(line.split()[0]) for line in lines]
    y4 = [float(line.split()[1]) for line in lines]
    
x4 = np.array(x4)
y4 = np.array(y4)

#popt, pcov = optimize.curve_fit(gaussian, x, y , [1, -22.5, 1] )

#print (popt)
fig = plt.figure(figsize=(15,9))

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.set_xlim([-1,0.1])
axes.plot(x1, y1, "darkviolet")
axes.plot(x2, y2, "limegreen")
axes.plot(x3, y3, "blue")
axes.plot(x4, y4, "red")

#axes.set_title("", fontsize=20)
axes.set_xlabel("V [V]", fontsize=25)
axes.set_ylabel("I  [$\\rho$ A]", fontsize=25)
axes.tick_params(axis="x", labelsize=20)
axes.tick_params(axis="y", labelsize=20)



plt.savefig("Is.pdf")
